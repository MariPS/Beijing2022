# %% [markdown]
# <h1>Creazione file per popolamento DB</h1>

# %% [markdown]
# Si vogliono creare tre file per il popolamento iniziale del database:
# - un file per la collezione <code>disciplines</code>, che contiene le informazioni ricavate da <code>entries_discipline</code> e <code>athletes</code>
# - un file per la collezione <code>medals</code>, che mantiene le informazioni ricavate da <code>medals</code> e <code>medals_total</code>
# - un file per la collezione <code>events</code>, che mantiene le informazioni ricavate da <code>events</code>

# %%
import pandas as pd
athletes = pd.read_csv("dataset/athletes.csv")
entries_discipline = pd.read_csv("dataset/entries_discipline.csv")
medals_total = pd.read_csv("dataset/medals_total.csv")
medals = pd.read_csv("dataset/medals.csv")
events = pd.read_csv("dataset/events.csv")

# %%
import json
import numpy as np

class NumpyEncoder(json.JSONEncoder):
    """ Custom encoder for numpy data types """
    def default(self, obj):
        if isinstance(obj, (np.int_, np.intc, np.intp, np.int8,
                            np.int16, np.int32, np.int64, np.uint8,
                            np.uint16, np.uint32, np.uint64)):

            return int(obj)

        elif isinstance(obj, (np.float_, np.float16, np.float32, np.float64)):
            return float(obj)

        elif isinstance(obj, (np.complex_, np.complex64, np.complex128)):
            return {'real': obj.real, 'imag': obj.imag}

        elif isinstance(obj, (np.ndarray,)):
            return obj.tolist()

        elif isinstance(obj, (np.bool_)):
            return bool(obj)

        elif isinstance(obj, (np.void)): 
            return None

        return json.JSONEncoder.default(self, obj)

# %% [markdown]
# <h2>Disciplines</h2>

# %%
entries_discipline.head()
# Out:
#              Discipline    F    M  Total
# 0         Alpine Skiing  153  157    310
# 1              Biathlon  106  107    213
# 2             Bobsleigh   46  117    163
# 3  Cross-Country Skiing  149  150    299
# 4               Curling   59   55    114

# %% [markdown]
# Il dataset ha quattro colonne, si vuole creare una collezione di documenti per le discipline in cui in ogni documento (disciplina) c'è la lista di tutti gli atleti di quella disciplina.

# %%
pd.merge(entries_discipline, athletes, left_on="Discipline", right_on="discipline", how="inner")
# Out:
#          Discipline    F    M  Total               name    short_name  gender  \
# 0     Alpine Skiing  153  157    310         ABDI Fayik        ABDI F    Male
# 1     Alpine Skiing  153  157    310      ABEDA Shannon       ABEDA S    Male
# 2     Alpine Skiing  153  157    310         AERNI Luca       AERNI L    Male
# 3     Alpine Skiing  153  157    310      AHMADI Atefeh      AHMADI A  Female
# 4     Alpine Skiing  153  157    310        AICHER Emma      AICHER E  Female
# ...             ...  ...  ...    ...                ...           ...     ...
# 2884  Speed Skating   78   87    165    ZAKHAROV Ruslan    ZAKHAROV R    Male
# 2885  Speed Skating   78   87    165  ZDRAHALOVA Nikola  ZDRAHALOVA N  Female
# 2886  Speed Skating   78   87    165        ZIOMEK Kaja      ZIOMEK K  Female
# 2887  Speed Skating   78   87    165       ZUREK Damian       ZUREK D    Male
# 2888  Speed Skating   78   87    165      ZUYEVA Maryna      ZUYEVA M  Female
#
#       birth_date             birth_place             birth_country  \
# 0     1997-10-07           SAN DIEGO, CA  United States of America
# 1     1996-05-15       FORT MCMURRAY, AB                    Canada
# 2     1993-03-27      CHATEL SAINT DENIS               Switzerland
# 3     2000-12-23                     NaN                       NaN
# 4     2003-11-13               SUNDSVALL                    Sweden
# ...          ...                     ...                       ...
# 2884  1987-03-24                   GORKI                      USSR
# 2885  1996-04-01  DVUR KRALOVE NAD LABEM            Czech Republic
# 2886  1997-08-03                   LUBIN                    Poland
# 2887  1999-09-17     TOMASZOW MAZOWIECKI                    Poland
# 2888  1992-03-20                   MINSK                   Belarus
#
#                        country country_code     discipline discipline_code  \
# 0                 Saudi Arabia          KSA  Alpine Skiing             ALP
# 1                      Eritrea          ERI  Alpine Skiing             ALP
# 2                  Switzerland          SUI  Alpine Skiing             ALP
# 3     Islamic Republic of Iran          IRI  Alpine Skiing             ALP
# 4                      Germany          GER  Alpine Skiing             ALP
# ...                        ...          ...            ...             ...
# 2884                       ROC          ROC  Speed Skating             SSK
# 2885            Czech Republic          CZE  Speed Skating             SSK
# 2886                    Poland          POL  Speed Skating             SSK
# 2887                    Poland          POL  Speed Skating             SSK
# 2888                   Belarus          BLR  Speed Skating             SSK
#
#           residence_place   residence_country  height_m/ft  \
# 0                 DHAHRAN        Saudi Arabia          NaN
# 1          LETHBRIDGE, AB              Canada          NaN
# 2                 MOLLENS         Switzerland          NaN
# 3                     NaN                 NaN          NaN
# 4           BERCHTESGADEN             Germany          NaN
# ...                   ...                 ...          ...
# 2884          KRASNOGORSK  Russian Federation   1.73/5'8''
# 2885     ZDAR NAD SAZAVOU      Czech Republic   1.71/5'7''
# 2886                LUBIN              Poland   1.69/5'6''
# 2887  TOMASZOW MAZOWIECKI              Poland  1.82/5'11''
# 2888                MINSK             Belarus  1.79/5'10''
#
#                                                     url
# 0     ../../../en/results/alpine-skiing/athlete-prof...
# 1     ../../../en/results/alpine-skiing/athlete-prof...
# 2     ../../../en/results/alpine-skiing/athlete-prof...
# 3     ../../../en/results/alpine-skiing/athlete-prof...
# 4     ../../../en/results/alpine-skiing/athlete-prof...
# ...                                                 ...
# 2884  ../../../en/results/speed-skating/athlete-prof...
# 2885  ../../../en/results/speed-skating/athlete-prof...
# 2886  ../../../en/results/speed-skating/athlete-prof...
# 2887  ../../../en/results/speed-skating/athlete-prof...
# 2888  ../../../en/results/speed-skating/athlete-prof...
#
# [2889 rows x 18 columns]

# %%
json_athletes = {}
list_json_athletes = []
json_entries_discipline = {}
list_json_entries_discipline = []

for row in range(entries_discipline.shape[0]):
    for col in range(entries_discipline.shape[1]):
        json_entries_discipline[entries_discipline.columns[col]] = entries_discipline.iloc[row,col]

    athletes_per_discipline = athletes.loc[athletes['discipline'] == entries_discipline['Discipline'][row]]  

    for athlete in range(athletes_per_discipline.shape[0]):
        for col in range(athletes_per_discipline.shape[1]):
            data = athletes_per_discipline.iloc[athlete,col]
            if isinstance(data, (np.int_, np.intc, np.intp, np.int8,
                            np.int16, np.int32, np.int64, np.uint8,
                            np.uint16, np.uint32, np.uint64)):
                if np.isnan(data):
                            pass
            elif data != data:
                pass
            else:
                json_athletes[athletes_per_discipline.columns[col]] = data
        list_json_athletes.append(json_athletes)
        json_athletes = {}

    json_entries_discipline['athletes'] = list_json_athletes
    list_json_entries_discipline.append(json_entries_discipline)
    
    list_json_athletes = []
    json_entries_discipline = {}

jsonfile = open("disciplines.json","w")
for data in list_json_entries_discipline:
    jsonfile.write(json.dumps(data, indent=3, cls=NumpyEncoder))
jsonfile.close()

# %% [markdown]
# Ogni documento nella collezione <code>Discipline</code> ha questo formato:

# %%
list_json_entries_discipline[0]
# Out:
# {'Discipline': 'Alpine Skiing',
#  'F': 153,
#  'M': 157,
#  'Total': 310,
#  'athletes': [{'name': 'ABDI Fayik',
#    'short_name': 'ABDI F',
#    'gender': 'Male',
#    'birth_date': '1997-10-07',
#    'birth_place': 'SAN DIEGO, CA',
#    'birth_country': 'United States of America',
#    'country': 'Saudi Arabia',
#    'country_code': 'KSA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'DHAHRAN',
#    'residence_country': 'Saudi Arabia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1051423-fayik-abdi.htm'},
#   {'name': 'ABEDA Shannon',
#    'short_name': 'ABEDA S',
#    'gender': 'Male',
#    'birth_date': '1996-05-15',
#    'birth_place': 'FORT MCMURRAY, AB',
#    'birth_country': 'Canada',
#    'country': 'Eritrea',
#    'country_code': 'ERI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LETHBRIDGE, AB',
#    'residence_country': 'Canada',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1052177-shannon-abeda.htm'},
#   {'name': 'AERNI Luca',
#    'short_name': 'AERNI L',
#    'gender': 'Male',
#    'birth_date': '1993-03-27',
#    'birth_place': 'CHATEL SAINT DENIS',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'MOLLENS',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048257-luca-aerni.htm'},
#   {'name': 'AHMADI Atefeh',
#    'short_name': 'AHMADI A',
#    'gender': 'Female',
#    'birth_date': '2000-12-23',
#    'country': 'Islamic Republic of Iran',
#    'country_code': 'IRI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1001848-atefeh-ahmadi.htm'},
#   {'name': 'AICHER Emma',
#    'short_name': 'AICHER E',
#    'gender': 'Female',
#    'birth_date': '2003-11-13',
#    'birth_place': 'SUNDSVALL',
#    'birth_country': 'Sweden',
#    'country': 'Germany',
#    'country_code': 'GER',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BERCHTESGADEN',
#    'residence_country': 'Germany',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1012881-emma-aicher.htm'},
#   {'name': 'ALESSANDRIA Arnaud',
#    'short_name': 'ALESSANDRIA A',
#    'gender': 'Male',
#    'birth_date': '1993-07-15',
#    'birth_place': 'MONTE CARLO',
#    'birth_country': 'Monaco',
#    'country': 'Monaco',
#    'country_code': 'MON',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SAINT-BON-TARENTAISE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1005712-arnaud-alessandria.htm'},
#   {'name': 'ALEXANDER Benjamin',
#    'short_name': 'ALEXANDER B',
#    'gender': 'Male',
#    'birth_date': '1983-05-08',
#    'birth_place': 'LONDON',
#    'birth_country': 'Great Britain',
#    'country': 'Jamaica',
#    'country_code': 'JAM',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'JACKSON, WY',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1064521-benjamin-alexander.htm'},
#   {'name': 'ALIC Esma',
#    'short_name': 'ALIC E',
#    'gender': 'Female',
#    'birth_date': '2002-10-08',
#    'birth_place': 'SARAJEVO',
#    'birth_country': 'Bosnia and Herzegovina',
#    'country': 'Bosnia and Herzegovina',
#    'country_code': 'BIH',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SARAJEVO',
#    'residence_country': 'Bosnia and Herzegovina',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1037238-esma-alic.htm'},
#   {'name': 'ALLEGRE Nils',
#    'short_name': 'ALLEGRE N',
#    'gender': 'Male',
#    'birth_date': '1994-01-02',
#    'birth_place': 'BRIANCON',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SAINT-CHAFFREY',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035753-nils-allegre.htm'},
#   {'name': 'ANDO Asa',
#    'short_name': 'ANDO A',
#    'gender': 'Female',
#    'birth_date': '1996-04-24',
#    'birth_place': 'ASAHIKAWA',
#    'birth_country': 'Japan',
#    'country': 'Japan',
#    'country_code': 'JPN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ASAHIKAWA',
#    'residence_country': 'Japan',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1042346-asa-ando.htm'},
#   {'name': 'ANDRIENKO Aleksander',
#    'short_name': 'ANDRIENKO A',
#    'gender': 'Male',
#    'birth_date': '1990-05-08',
#    'birth_country': 'Russian Federation',
#    'country': 'ROC',
#    'country_code': 'ROC',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'KALUGA',
#    'residence_country': 'Russian Federation',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1038070-aleksander-andrienko.htm'},
#   {'name': 'ANTONIOU Ioannis',
#    'short_name': 'ANTONIOU I',
#    'gender': 'Male',
#    'birth_date': '1995-01-27',
#    'birth_place': 'LAMIA',
#    'birth_country': 'Greece',
#    'country': 'Greece',
#    'country_code': 'GRE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'KARPENISI',
#    'residence_country': 'Greece',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1044843-ioannis-antoniou.htm'},
#   {'name': 'AOUICH Yassine',
#    'short_name': 'AOUICH Y',
#    'gender': 'Male',
#    'birth_date': '1990-11-17',
#    'birth_place': 'IFRANE',
#    'birth_country': 'Morocco',
#    'country': 'Morocco',
#    'country_code': 'MAR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'NICE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1053526-yassine-aouich.htm'},
#   {'name': 'ARAMBURO Emilia',
#    'short_name': 'ARAMBURO E',
#    'gender': 'Female',
#    'birth_date': '2002-08-13',
#    'country': 'Chile',
#    'country_code': 'CHI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LA PARVA',
#    'residence_country': 'Chile',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1137344-emilia-aramburo.htm'},
#   {'name': 'ARBEZ Tess',
#    'short_name': 'ARBEZ T',
#    'gender': 'Female',
#    'birth_date': '1997-12-01',
#    'birth_place': 'SAINT-JULIEN-EN-GENEVOIS',
#    'birth_country': 'France',
#    'country': 'Ireland',
#    'country_code': 'IRL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'VETRAZ-MONTHOUX',
#    'residence_country': 'Ireland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015156-tess-arbez.htm'},
#   {'name': 'ARNOUK Cesar',
#    'short_name': 'ARNOUK C',
#    'gender': 'Male',
#    'birth_date': '2000-11-08',
#    'birth_place': 'TRIPOLI',
#    'birth_country': 'Libya',
#    'country': 'LBN',
#    'country_code': 'LBN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'MONTREAL, QC',
#    'residence_country': 'Canada',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1053546-cesar-arnouk.htm'},
#   {'name': 'ARONSSON ELFMAN Hanna',
#    'short_name': 'ARONSSON ELFMAN H',
#    'gender': 'Female',
#    'birth_date': '2002-12-29',
#    'birth_place': 'KARLSTAD',
#    'birth_country': 'Sweden',
#    'country': 'Sweden',
#    'country_code': 'SWE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'KARLSTAD',
#    'residence_country': 'Sweden',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1054349-hanna-aronsson-elfman.htm'},
#   {'name': 'BAILET Matthieu',
#    'short_name': 'BAILET M',
#    'gender': 'Male',
#    'birth_date': '1996-04-23',
#    'birth_place': 'NICE',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'NICE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035755-matthieu-bailet.htm'},
#   {'name': 'BARUZZI FARRIOL Francesca',
#    'short_name': 'BARUZZI FARRIOL F',
#    'gender': 'Female',
#    'birth_date': '1998-07-22',
#    'birth_place': 'SAN CARLOS DE BARILOCHE',
#    'birth_country': 'Argentina',
#    'country': 'Argentina',
#    'country_code': 'ARG',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BUENOS AIRES',
#    'residence_country': 'Argentina',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1037536-francesca-baruzzi-farriol.htm'},
#   {'name': 'BASSINO Marta',
#    'short_name': 'BASSINO M',
#    'gender': 'Female',
#    'birth_date': '1996-02-27',
#    'birth_place': 'CUNEO',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BORGO SAN DALMAZZO',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015217-marta-bassino.htm'},
#   {'name': 'BAUMANN Romed',
#    'short_name': 'BAUMANN R',
#    'gender': 'Male',
#    'birth_date': '1986-01-14',
#    'birth_place': 'ST. JOHANN IN TIROL',
#    'birth_country': 'Austria',
#    'country': 'Germany',
#    'country_code': 'GER',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'KIEFERSFELDEN',
#    'residence_country': 'Germany',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1012758-romed-baumann.htm'},
#   {'name': 'BENNETT Bryce',
#    'short_name': 'BENNETT B',
#    'gender': 'Male',
#    'birth_date': '1992-07-14',
#    'birth_place': 'TRUCKEE, CA',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'TRUCKEE, CA',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041196-bryce-bennett.htm'},
#   {'name': 'BIRKNER de MIGUEL Tomas',
#    'short_name': 'BIRKNER de MIGUEL',
#    'gender': 'Male',
#    'birth_date': '1997-03-05',
#    'birth_place': 'SAN CARLOS DE BARILOCHE',
#    'birth_country': 'Argentina',
#    'country': 'Argentina',
#    'country_code': 'ARG',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SAN CARLOS DE BARILOCHE',
#    'residence_country': 'Argentina',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1037538-tomas-birkner-de-miguel.htm'},
#   {'name': 'BONDARE Liene',
#    'short_name': 'BONDARE L',
#    'gender': 'Female',
#    'birth_date': '1996-02-21',
#    'birth_place': 'RIGA',
#    'birth_country': 'Latvia',
#    'country': 'Latvia',
#    'country_code': 'LAT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'RIGA',
#    'residence_country': 'Latvia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1038237-liene-bondare.htm'},
#   {'name': 'BRAATHEN Lucas',
#    'short_name': 'BRAATHEN L',
#    'gender': 'Male',
#    'birth_date': '2000-04-19',
#    'birth_place': 'OSLO',
#    'birth_country': 'Norway',
#    'country': 'Norway',
#    'country_code': 'NOR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'OSLO',
#    'residence_country': 'Norway',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1031305-lucas-braathen.htm'},
#   {'name': 'BRANCAL Ricardo',
#    'short_name': 'BRANCAL R',
#    'gender': 'Male',
#    'birth_date': '1996-05-17',
#    'country': 'Portugal',
#    'country_code': 'POR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1056770-ricardo-brancal.htm'},
#   {'name': 'BREITFUSS KAMMERLANDER Simon',
#    'short_name': 'BREITFUSS KAMMERL.',
#    'gender': 'Male',
#    'birth_date': '1992-11-29',
#    'birth_place': 'ZAMS',
#    'birth_country': 'Austria',
#    'country': 'Bolivia',
#    'country_code': 'BOL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LA PAZ',
#    'residence_country': 'Bolivia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1060101-simon-breitfuss-kammerlander.htm'},
#   {'name': 'BRENNSTEINER Stefan',
#    'short_name': 'BRENNSTEINER S',
#    'gender': 'Male',
#    'birth_date': '1991-10-03',
#    'birth_place': 'ZELL AM SEE',
#    'birth_country': 'Austria',
#    'country': 'Austria',
#    'country_code': 'AUT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'NIEDERNSILL',
#    'residence_country': 'Austria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1005371-stefan-brennsteiner.htm'},
#   {'name': 'BRIGNONE Federica',
#    'short_name': 'BRIGNONE F',
#    'gender': 'Female',
#    'birth_date': '1990-07-14',
#    'birth_place': 'MILAN',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LA SALLE',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015230-federica-brignone.htm'},
#   {'name': 'BRUNNER Stephanie',
#    'short_name': 'BRUNNER S',
#    'gender': 'Female',
#    'birth_date': '1994-02-20',
#    'birth_place': 'SCHWAZ',
#    'birth_country': 'Austria',
#    'country': 'Austria',
#    'country_code': 'AUT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'INNSBRUCK',
#    'residence_country': 'Austria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1005308-stephanie-brunner.htm'},
#   {'name': 'BUCIK Ana',
#    'short_name': 'BUCIK A',
#    'gender': 'Female',
#    'birth_date': '1993-07-21',
#    'birth_place': 'NOVA GORICA',
#    'birth_country': 'Slovenia',
#    'country': 'Slovenia',
#    'country_code': 'SLO',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'NOVA GORICA',
#    'residence_country': 'Slovenia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1050938-ana-bucik.htm'},
#   {'name': 'CAPOVA Gabriela',
#    'short_name': 'CAPOVA G',
#    'gender': 'Female',
#    'birth_date': '1993-10-08',
#    'birth_place': 'OSTRAVA',
#    'birth_country': 'Czech Republic',
#    'country': 'Czech Republic',
#    'country_code': 'CZE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BRUSPERK',
#    'residence_country': 'Czech Republic',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1013895-gabriela-capova.htm'},
#   {'name': 'CARIKCIOGLU Ozlem',
#    'short_name': 'CARIKCIOGLU O',
#    'gender': 'Female',
#    'birth_date': '1994-01-01',
#    'birth_place': 'ISTANBUL',
#    'birth_country': 'Turkey',
#    'country': 'Turkey',
#    'country_code': 'TUR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ISTANBUL',
#    'residence_country': 'Turkey',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1167472-ozlem-carikcioglu.htm'},
#   {'name': 'CASHMAN Keely',
#    'short_name': 'CASHMAN K',
#    'gender': 'Female',
#    'birth_date': '1999-04-04',
#    'birth_place': 'SONORA, CA',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'STRAWBERRY, CA',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041220-keely-cashman.htm'},
#   {'name': 'CATER Martin',
#    'short_name': 'CATER M',
#    'gender': 'Male',
#    'birth_date': '1992-12-20',
#    'birth_place': 'CELJE',
#    'birth_country': 'Slovenia',
#    'country': 'Slovenia',
#    'country_code': 'SLO',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'CELJE',
#    'residence_country': 'Slovenia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1050985-martin-cater.htm'},
#   {'name': 'CAVIEZEL Gino',
#    'short_name': 'CAVIEZEL G',
#    'gender': 'Male',
#    'birth_date': '1992-06-23',
#    'birth_place': 'CHUR',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'PFAEFFIKON',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048318-gino-caviezel.htm'},
#   {'name': 'CERUTTI Camille',
#    'short_name': 'CERUTTI C',
#    'gender': 'Female',
#    'birth_date': '1998-12-22',
#    'birth_place': 'MARSEILLES',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ALBERTVILLE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035756-camille-cerutti.htm'},
#   {'name': 'CHABLOZ Yannick',
#    'short_name': 'CHABLOZ Y',
#    'gender': 'Male',
#    'birth_date': '1999-03-17',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'NIDWALDEN',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048323-yannick-chabloz.htm'},
#   {'name': 'CLAREY Johan',
#    'short_name': 'CLAREY J',
#    'gender': 'Male',
#    'birth_date': '1981-01-08',
#    'birth_place': 'ANNECY',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ANNECY',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035757-johan-clarey.htm'},
#   {'name': 'CLERC Mialitiana',
#    'short_name': 'CLERC M',
#    'gender': 'Female',
#    'birth_date': '2001-11-16',
#    'birth_place': 'ANTANANARIVO',
#    'birth_country': 'Madagascar',
#    'country': 'Madagascar',
#    'country_code': 'MAD',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'HAUTE-SAVOI',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1061565-mialitiana-clerc.htm'},
#   {'name': 'COCHRAN-SIEGLE Ryan',
#    'short_name': 'COCHRAN-SIEGLE R',
#    'gender': 'Male',
#    'birth_date': '1992-03-27',
#    'birth_place': 'BURLINGTON, VT',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'STARKSBORO, VT',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041237-ryan-cochran-siegle.htm'},
#   {'name': 'CONSTANTIN Maria Ioana',
#    'short_name': 'CONSTANTIN MI',
#    'gender': 'Female',
#    'birth_date': '2001-01-05',
#    'country': 'Romania',
#    'country_code': 'ROU',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'PREDEAL',
#    'residence_country': 'Romania',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1025538-maria-ioana-constantin.htm'},
#   {'name': 'CRAWFORD James',
#    'short_name': 'CRAWFORD J',
#    'gender': 'Male',
#    'birth_date': '1997-05-03',
#    'birth_place': 'TORONTO, ON',
#    'birth_country': 'Canada',
#    'country': 'Canada',
#    'country_code': 'CAN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'TORONTO, ON',
#    'residence_country': 'Canada',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1045541-james-crawford.htm'},
#   {'name': 'CURTONI Elena',
#    'short_name': 'CURTONI E',
#    'gender': 'Female',
#    'birth_date': '1991-02-03',
#    'birth_place': 'MORBEGNO',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'COSIO VALTELLINO',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015231-elena-curtoni.htm'},
#   {'name': 'CZAPSKA Zuzanna',
#    'short_name': 'CZAPSKA Z',
#    'gender': 'Female',
#    'birth_date': '1998-08-04',
#    'birth_place': 'WARSAW',
#    'birth_country': 'Poland',
#    'country': 'Poland',
#    'country_code': 'POL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'PIEKIELNIK',
#    'residence_country': 'Poland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1032101-zuzanna-czapska.htm'},
#   {'name': 'DANIOTH Aline',
#    'short_name': 'DANIOTH A',
#    'gender': 'Female',
#    'birth_date': '1998-03-12',
#    'birth_place': 'ANDERMATT',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ANDERMATT',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048332-aline-danioth.htm'},
#   {'name': 'de ALIPRANDINI Luca',
#    'short_name': 'de ALIPRANDINI L',
#    'gender': 'Male',
#    'birth_date': '1990-09-01',
#    'birth_place': 'CLES',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'RIVA DEL GARDA',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1009685-luca-de-aliprandini.htm'},
#   {'name': 'DEHARI Dardan',
#    'short_name': 'DEHARI D',
#    'gender': 'Male',
#    'birth_date': '1990-08-23',
#    'birth_place': 'TETOVO',
#    'birth_country': 'North Macedonia',
#    'country': 'North Macedonia',
#    'country_code': 'MKD',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'TETOVO',
#    'residence_country': 'North Macedonia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1059172-dardan-dehari.htm'},
#   {'name': 'DELAGO Nadia',
#    'short_name': 'DELAGO N',
#    'gender': 'Female',
#    'birth_date': '1997-11-12',
#    'birth_place': 'BRESSANONE',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SELVA DI VAL GARDENA',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015126-nadia-delago.htm'},
#   {'name': 'DELAGO Nicol',
#    'short_name': 'DELAGO N',
#    'gender': 'Female',
#    'birth_date': '1996-01-05',
#    'birth_place': 'BRIXEN',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SELVA DI VAL GARDENA',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015116-nicol-delago.htm'},
#   {'name': 'DELLA MEA Lara',
#    'short_name': 'DELLA MEA L',
#    'gender': 'Female',
#    'birth_date': '1999-01-10',
#    'birth_place': 'TRIESTE',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'TARVISIO',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015117-lara-della-mea.htm'},
#   {'name': 'DICKSON SOMMERS Rodolfo Roberto',
#    'short_name': 'DICKSON SOMMERS RR',
#    'gender': 'Male',
#    'birth_date': '1997-07-11',
#    'birth_place': 'PUERTO VALLARTA',
#    'birth_country': 'Mexico',
#    'country': 'Mexico',
#    'country_code': 'MEX',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'VANCOUVER',
#    'residence_country': 'Canada',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1044605-rodolfo-roberto-dickson-sommers.htm'},
#   {'name': 'DIREZ Clara',
#    'short_name': 'DIREZ C',
#    'gender': 'Female',
#    'birth_date': '1995-04-05',
#    'birth_place': 'SALLANCHES',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'NOTRE DAME DE BELLECOMBE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035758-clara-direz.htm'},
#   {'name': 'DRUKAROV Andrej',
#    'short_name': 'DRUKAROV A',
#    'gender': 'Male',
#    'birth_date': '1999-05-10',
#    'birth_place': 'VILNIUS',
#    'birth_country': 'Lithuania',
#    'country': 'Lithuania',
#    'country_code': 'LTU',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ANDERMATT',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041780-andrej-drukarov.htm'},
#   {'name': 'DUBOVSKA Martina',
#    'short_name': 'DUBOVSKA M',
#    'gender': 'Female',
#    'birth_date': '1992-02-27',
#    'birth_place': 'TRINEC',
#    'birth_country': 'Czech Republic',
#    'country': 'Czech Republic',
#    'country_code': 'CZE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LIPTOVSKY MIKULAS',
#    'residence_country': 'Slovakia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1013894-martina-dubovska.htm'},
#   {'name': 'DUERR Lena',
#    'short_name': 'DUERR L',
#    'gender': 'Female',
#    'birth_date': '1991-08-04',
#    'birth_place': 'MUNICH',
#    'birth_country': 'Germany',
#    'country': 'Germany',
#    'country_code': 'GER',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'GARMISCH-PARTENKIRCHEN',
#    'residence_country': 'Germany',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1012697-lena-duerr.htm'},
#   {'name': 'DVORNIK Neja',
#    'short_name': 'DVORNIK N',
#    'gender': 'Female',
#    'birth_date': '2001-01-06',
#    'birth_place': 'SLOVENJ GRADEC',
#    'birth_country': 'Slovenia',
#    'country': 'Slovenia',
#    'country_code': 'SLO',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SLOVENJ GRADEC',
#    'residence_country': 'Slovenia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1051154-neja-dvornik.htm'},
#   {'name': 'DYRBYE Casper',
#    'short_name': 'DYRBYE C',
#    'gender': 'Male',
#    'birth_date': '1996-06-19',
#    'birth_place': 'BROENDBY',
#    'birth_country': 'Denmark',
#    'country': 'Denmark',
#    'country_code': 'DEN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'VALLENSBAEK STRAND',
#    'residence_country': 'Denmark',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1025269-casper-dyrbye.htm'},
#   {'name': 'ELLENBERGER Andrea',
#    'short_name': 'ELLENBERGER A',
#    'gender': 'Female',
#    'birth_date': '1993-03-22',
#    'birth_place': 'HERGISWIL',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'HERGISWIL',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048344-andrea-ellenberger.htm'},
#   {'name': 'ESCOBAR Sarah',
#    'short_name': 'ESCOBAR S',
#    'gender': 'Female',
#    'birth_date': '2002-02-01',
#    'birth_place': 'NEW YORK, NY',
#    'birth_country': 'United States of America',
#    'country': 'Ecuador',
#    'country_code': 'ECU',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'COLCHESTER, VT',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1055518-sarah-escobar.htm'},
#   {'name': 'ETXEZARRETA Adur',
#    'short_name': 'ETXEZARRETA A',
#    'gender': 'Male',
#    'birth_date': '1996-01-27',
#    'country': 'Spain',
#    'country_code': 'ESP',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ARESO',
#    'residence_country': 'Spain',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1043333-adur-etxezarreta.htm'},
#   {'name': 'FAIVRE Mathieu',
#    'short_name': 'FAIVRE M',
#    'gender': 'Male',
#    'birth_date': '1992-01-18',
#    'birth_place': 'NICE',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ALBERTVILLE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035759-mathieu-faivre.htm'},
#   {'name': 'FAVROT Thibaut',
#    'short_name': 'FAVROT T',
#    'gender': 'Male',
#    'birth_date': '1994-12-22',
#    'birth_place': 'STRASBOURG',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ALBERTVILLE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035760-thibaut-favrot.htm'},
#   {'name': 'FELLER Manuel',
#    'short_name': 'FELLER M',
#    'gender': 'Male',
#    'birth_date': '1992-10-13',
#    'birth_place': 'ST. JOHANN IN TIROL',
#    'birth_country': 'Austria',
#    'country': 'Austria',
#    'country_code': 'AUT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'FIEBERBRUNN',
#    'residence_country': 'Austria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1005374-manuel-feller.htm'},
#   {'name': 'FERK SAIONI Marusa',
#    'short_name': 'FERK SAIONI M',
#    'gender': 'Female',
#    'birth_date': '1988-09-27',
#    'birth_place': 'JESENICE',
#    'birth_country': 'The Federal Republic of Yugoslavia',
#    'country': 'Slovenia',
#    'country_code': 'SLO',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BLEJSKA DOBRAVA',
#    'residence_country': 'Slovenia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1050986-marusa-ferk-saioni.htm'},
#   {'name': 'FERMBAECK Elsa',
#    'short_name': 'FERMBAECK E',
#    'gender': 'Female',
#    'birth_date': '1998-03-28',
#    'birth_place': 'OESTERSUND',
#    'birth_country': 'Sweden',
#    'country': 'Sweden',
#    'country_code': 'SWE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'VEMHAN',
#    'residence_country': 'Sweden',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1054353-elsa-fermbaeck.htm'},
#   {'name': 'FERSTL Josef',
#    'short_name': 'FERSTL J',
#    'gender': 'Male',
#    'birth_date': '1988-12-29',
#    'birth_place': 'TRAUNSTEIN',
#    'birth_country': 'Germany',
#    'country': 'Germany',
#    'country_code': 'GER',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1012681-josef-ferstl.htm'},
#   {'name': 'FEUZ Beat',
#    'short_name': 'FEUZ B',
#    'gender': 'Male',
#    'birth_date': '1987-02-11',
#    'birth_place': 'SCHANGNAU',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'INNSBRUCK',
#    'residence_country': 'Austria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048352-beat-feuz.htm'},
#   {'name': 'FLAHERTY William C.',
#    'short_name': 'FLAHERTY WC',
#    'gender': 'Male',
#    'birth_date': '2004-05-09',
#    'birth_place': 'CINCINNATI, OH',
#    'birth_country': 'United States of America',
#    'country': 'Puerto Rico',
#    'country_code': 'PUR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'RIO GRANDE',
#    'residence_country': 'Puerto Rico',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1106753-william-c-flaherty.htm'},
#   {'name': 'FLURY Jasmine',
#    'short_name': 'FLURY J',
#    'gender': 'Female',
#    'birth_date': '1993-09-16',
#    'birth_place': 'DAVOS',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'DAVOS',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048359-jasmine-flury.htm'},
#   {'name': 'FORD Tommy',
#    'short_name': 'FORD T',
#    'gender': 'Male',
#    'birth_date': '1989-03-20',
#    'birth_place': 'HANOVER, NH',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BEND, OR',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041243-tommy-ford.htm'},
#   {'name': 'FOSS-SOLEVAAG Sebastian',
#    'short_name': 'FOSS-SOLEVAAG S',
#    'gender': 'Male',
#    'birth_date': '1991-07-13',
#    'birth_place': 'AALESUND',
#    'birth_country': 'Norway',
#    'country': 'Norway',
#    'country_code': 'NOR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'OSLO',
#    'residence_country': 'Norway',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1031301-sebastian-foss-solevaag.htm'},
#   {'name': 'FRANZ Max',
#    'short_name': 'FRANZ M',
#    'gender': 'Male',
#    'birth_date': '1989-09-01',
#    'birth_place': 'KLAGENFURT',
#    'birth_country': 'Austria',
#    'country': 'Austria',
#    'country_code': 'AUT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'WEISSBRIACH',
#    'residence_country': 'Austria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1005377-max-franz.htm'},
#   {'name': 'FRASSE SOMBET Coralie',
#    'short_name': 'FRASSE SOMBET C',
#    'gender': 'Female',
#    'birth_date': '1991-04-08',
#    'birth_place': "SAINT-MARTIN-D'HERES",
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LA RAVOIRE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035761-coralie-frasse-sombet.htm'},
#   {'name': 'FRIDGEIRSDOTTIR Holmfridur Dora',
#    'short_name': 'FRIDGEIRSDOTTIR HD',
#    'gender': 'Female',
#    'birth_date': '1998-01-08',
#    'birth_place': 'REYKJAVIK',
#    'birth_country': 'Iceland',
#    'country': 'Iceland',
#    'country_code': 'ISL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1054913-holmfridur-dora-fridgeirsdottir.htm'},
#   {'name': 'GAGNON Marie-Michele',
#    'short_name': 'GAGNON MM',
#    'gender': 'Female',
#    'birth_date': '1989-04-25',
#    'birth_place': 'LAC-ETCHEMIN, QC',
#    'birth_country': 'Canada',
#    'country': 'Canada',
#    'country_code': 'CAN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LAKE TAHOE, CA',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1045548-marie-michele-gagnon.htm'},
#   {'name': 'GALLHUBER Katharina',
#    'short_name': 'GALLHUBER K',
#    'gender': 'Female',
#    'birth_date': '1997-06-16',
#    'birth_place': 'SCHEIBBS',
#    'birth_country': 'Austria',
#    'country': 'Austria',
#    'country_code': 'AUT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'GOESTLING AN DER YBBS',
#    'residence_country': 'Austria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1005311-katharina-gallhuber.htm'},
#   {'name': 'GANONG Travis',
#    'short_name': 'GANONG T',
#    'gender': 'Male',
#    'birth_date': '1988-07-14',
#    'birth_place': 'TRUCKEE, CA',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'OLYMPIC VALLEY, CA',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041244-travis-ganong.htm'},
#   {'name': 'GASIENICA-DANIEL Maryna',
#    'short_name': 'GASIENICA-DANIEL M',
#    'gender': 'Female',
#    'birth_date': '1994-02-19',
#    'birth_place': 'ZAKOPANE',
#    'birth_country': 'Poland',
#    'country': 'Poland',
#    'country_code': 'POL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ZAKOPANE',
#    'residence_country': 'Poland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1032070-maryna-gasienica-daniel.htm'},
#   {'name': 'GATTI Matteo',
#    'short_name': 'GATTI M',
#    'gender': 'Male',
#    'birth_date': '2001-05-14',
#    'birth_place': 'SAN MARINO',
#    'birth_country': 'San Marino',
#    'country': 'San Marino',
#    'country_code': 'SMR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SAN MARINO',
#    'residence_country': 'San Marino',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1042070-matteo-gatti.htm'},
#   {'name': 'GAUCHE Laura',
#    'short_name': 'GAUCHE L',
#    'gender': 'Female',
#    'birth_date': '1995-03-04',
#    'birth_place': 'MOUTIERS',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ALBERTVILLE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035750-laura-gauche.htm'},
#   {'name': 'GAUTHIER Tiffany',
#    'short_name': 'GAUTHIER T',
#    'gender': 'Female',
#    'birth_date': '1993-12-02',
#    'birth_place': 'SAINT-ETIENNE',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'TIGNES',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035762-tiffany-gauthier.htm'},
#   {'name': 'GIEZENDANNER Blaise',
#    'short_name': 'GIEZENDANNER B',
#    'gender': 'Male',
#    'birth_date': '1991-11-29',
#    'birth_place': 'CHAMONIX',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'CHAMONIX',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035763-blaise-giezendanner.htm'},
#   {'name': 'GIM Sohui',
#    'short_name': 'GIM S',
#    'gender': 'Female',
#    'birth_date': '1996-08-19',
#    'birth_place': 'GANGWON',
#    'birth_country': 'Republic of Korea',
#    'country': 'Republic of Korea',
#    'country_code': 'KOR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'GANGWON',
#    'residence_country': 'Republic of Korea',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1036944-sohui-gim.htm'},
#   {'name': 'GISIN Michelle',
#    'short_name': 'GISIN M',
#    'gender': 'Female',
#    'birth_date': '1993-12-05',
#    'birth_place': 'SAMEDAN',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ENGELBERG',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048385-michelle-gisin.htm'},
#   {'name': 'GOGGIA Sofia',
#    'short_name': 'GOGGIA S',
#    'gender': 'Female',
#    'birth_date': '1992-11-15',
#    'birth_place': 'BERGAMO',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BERGAMO',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015232-sofia-goggia.htm'},
#   {'name': 'GORDEEV Maksim',
#    'short_name': 'GORDEEV M',
#    'gender': 'Male',
#    'birth_date': '1995-11-01',
#    'birth_place': 'KARAKOL',
#    'birth_country': 'Kyrgyzstan',
#    'country': 'Kyrgyzstan',
#    'country_code': 'KGZ',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'KARAKOL',
#    'residence_country': 'Kyrgyzstan',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1004932-maksim-gordeev.htm'},
#   {'name': 'GORNOSTAEVA Anastasia',
#    'short_name': 'GORNOSTAEVA A',
#    'gender': 'Female',
#    'birth_date': '1999-12-31',
#    'country': 'ROC',
#    'country_code': 'ROC',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'MOSCOW',
#    'residence_country': 'Russian Federation',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1038071-anastasia-gornostaeva.htm'},
#   {'name': 'GOUTT Yohan Goncalves',
#    'short_name': 'GOUTT YG',
#    'gender': 'Male',
#    'birth_date': '1994-12-20',
#    'birth_place': 'SURESNES',
#    'birth_country': 'France',
#    'country': 'Timor-Leste',
#    'country_code': 'TLS',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'PARIS',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1002308-yohan-goncalves-goutt.htm'},
#   {'name': 'GOWER Jack',
#    'short_name': 'GOWER J',
#    'gender': 'Male',
#    'birth_date': '1994-05-26',
#    'birth_place': 'CHICHESTER',
#    'birth_country': 'Great Britain',
#    'country': 'Ireland',
#    'country_code': 'IRL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'CHICHESTER',
#    'residence_country': 'Great Britain',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015506-jack-gower.htm'},
#   {'name': 'GRAY Cassidy',
#    'short_name': 'GRAY C',
#    'gender': 'Female',
#    'birth_date': '2001-01-25',
#    'birth_place': 'CALGARY, AB',
#    'birth_country': 'Canada',
#    'country': 'Canada',
#    'country_code': 'CAN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'INVERMERE, BC',
#    'residence_country': 'Canada',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1045553-cassidy-gray.htm'},
#   {'name': 'GRENIER Valerie',
#    'short_name': 'GRENIER V',
#    'gender': 'Female',
#    'birth_date': '1996-10-30',
#    'birth_place': 'OTTAWA, ON',
#    'birth_country': 'Canada',
#    'country': 'Canada',
#    'country_code': 'CAN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ST-ISIDORE, QC',
#    'residence_country': 'Canada',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1045540-valerie-grenier.htm'},
#   {'name': 'GUERILLOT Vanina',
#    'short_name': 'GUERILLOT V',
#    'gender': 'Female',
#    'birth_date': '2002-07-03',
#    'birth_place': 'GRENOBLE',
#    'birth_country': 'France',
#    'country': 'Portugal',
#    'country_code': 'POR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BOZEL',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1056760-vanina-guerillot.htm'},
#   {'name': 'GUEST Charlie',
#    'short_name': 'GUEST C',
#    'gender': 'Female',
#    'birth_date': '1993-12-30',
#    'birth_place': 'EDINBURGH',
#    'birth_country': 'Great Britain',
#    'country': 'Great Britain',
#    'country_code': 'GBR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'PERTH',
#    'residence_country': 'Great Britain',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1045688-charlie-guest.htm'},
#   {'name': 'GULLI Anita',
#    'short_name': 'GULLI A',
#    'gender': 'Female',
#    'birth_date': '1998-06-26',
#    'birth_place': 'TURIN',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'TURIN',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015119-anita-gulli.htm'},
#   {'name': 'GUT-BEHRAMI Lara',
#    'short_name': 'GUT-BEHRAMI L',
#    'gender': 'Female',
#    'birth_date': '1991-04-27',
#    'birth_place': 'LUGANO',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'UDINE',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048401-lara-gut-behrami.htm'},
#   {'name': 'HAASER Raphael',
#    'short_name': 'HAASER R',
#    'gender': 'Male',
#    'birth_date': '1997-09-17',
#    'birth_country': 'Austria',
#    'country': 'Austria',
#    'country_code': 'AUT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'MAURACH',
#    'residence_country': 'Austria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1005379-raphael-haaser.htm'},
#   {'name': 'HAEHLEN Joana',
#    'short_name': 'HAEHLEN J',
#    'gender': 'Female',
#    'birth_date': '1992-01-23',
#    'birth_place': 'BELP',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LENK IM SIMMENTAL',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048506-joana-haehlen.htm'},
#   {'name': 'HARUTYUNYAN Harutyun',
#    'short_name': 'HARUTYUNYAN H',
#    'gender': 'Male',
#    'birth_date': '2000-04-05',
#    'country': 'Armenia',
#    'country_code': 'ARM',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1045632-harutyun-harutyunyan.htm'},
#   {'name': 'HAUGAN Timon',
#    'short_name': 'HAUGAN T',
#    'gender': 'Male',
#    'birth_date': '1996-12-27',
#    'birth_place': 'STOREN',
#    'birth_country': 'Norway',
#    'country': 'Norway',
#    'country_code': 'NOR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LORENSKOG',
#    'residence_country': 'Norway',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1031302-timon-haugan.htm'},
#   {'name': 'HECTOR Sara',
#    'short_name': 'HECTOR S',
#    'gender': 'Female',
#    'birth_date': '1992-09-04',
#    'birth_place': 'SANDVIKEN',
#    'birth_country': 'Sweden',
#    'country': 'Sweden',
#    'country_code': 'SWE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'DUVED',
#    'residence_country': 'Sweden',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1054355-sara-hector.htm'},
#   {'name': 'HEMETSBERGER Daniel',
#    'short_name': 'HEMETSBERGER D',
#    'gender': 'Male',
#    'birth_date': '1991-05-23',
#    'birth_place': 'VOECKLABRUCK',
#    'birth_country': 'Austria',
#    'country': 'Austria',
#    'country_code': 'AUT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'NUSSDORF AM ATTERSEE',
#    'residence_country': 'Austria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1005380-daniel-hemetsberger.htm'},
#   {'name': 'HENSIEN Katie',
#    'short_name': 'HENSIEN K',
#    'gender': 'Female',
#    'birth_date': '1999-12-01',
#    'birth_place': 'REDMOND, WA',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'PARK CITY, UT',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041221-katie-hensien.htm'},
#   {'name': 'HILZINGER Jessica',
#    'short_name': 'HILZINGER J',
#    'gender': 'Female',
#    'birth_date': '1997-05-26',
#    'birth_place': 'GRABS',
#    'birth_country': 'Switzerland',
#    'country': 'Germany',
#    'country_code': 'GER',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'OBERSTDORF',
#    'residence_country': 'Germany',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1012853-jessica-hilzinger.htm'},
#   {'name': 'HINTERMANN Niels',
#    'short_name': 'HINTERMANN N',
#    'gender': 'Male',
#    'birth_date': '1995-05-05',
#    'birth_place': 'BULACH',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ZURICH',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1048538-niels-hintermann.htm'},
#   {'name': 'HO Ping-Jui',
#    'short_name': 'HO PJ',
#    'gender': 'Male',
#    'birth_date': '1998-10-29',
#    'birth_place': 'TAIPEI CITY',
#    'birth_country': 'Chinese Taipei',
#    'country': 'Chinese Taipei',
#    'country_code': 'TPE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'WAIDHOFEN AN DER YBBS',
#    'residence_country': 'Austria',
# ...
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1013712-komiljon-tukhtaev.htm'},
#   {'name': 'TVIBERG Maria Therese',
#    'short_name': 'TVIBERG MT',
#    'gender': 'Female',
#    'birth_date': '1994-04-07',
#    'birth_place': 'BERGEN',
#    'birth_country': 'Norway',
#    'country': 'Norway',
#    'country_code': 'NOR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'OSLO',
#    'residence_country': 'Norway',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1031294-maria-therese-tviberg.htm'},
#   {'name': 'USTA Berkin',
#    'short_name': 'USTA B',
#    'gender': 'Male',
#    'birth_date': '2000-05-29',
#    'country': 'Turkey',
#    'country_code': 'TUR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'BURSA',
#    'residence_country': 'Turkey',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1001625-berkin-usta.htm'},
#   {'name': 'van den BROECKE Dries',
#    'short_name': 'van den BROECKE D',
#    'gender': 'Male',
#    'birth_date': '1995-05-10',
#    'birth_place': 'GHENT',
#    'birth_country': 'Belgium',
#    'country': 'Belgium',
#    'country_code': 'BEL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'GHENT',
#    'residence_country': 'Belgium',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1045286-dries-van-den-broecke.htm'},
#   {'name': 'VERDU Joan',
#    'short_name': 'VERDU J',
#    'gender': 'Male',
#    'birth_date': '1995-05-23',
#    'birth_place': 'ESCALDES-ENGORDANY',
#    'birth_country': 'Andorra',
#    'country': 'Andorra',
#    'country_code': 'AND',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ANDORRA LA VELLA',
#    'residence_country': 'Andorra',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1032468-joan-verdu.htm'},
#   {'name': 'VESTERSTEIN Kaitlyn',
#    'short_name': 'VESTERSTEIN K',
#    'gender': 'Female',
#    'birth_date': '1999-06-21',
#    'birth_place': 'DULUTH, MN',
#    'birth_country': 'United States of America',
#    'country': 'Estonia',
#    'country_code': 'EST',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SALT LAKE CITY, UT',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1016193-kaitlyn-vesterstein.htm'},
#   {'name': 'VIANO Richardson',
#    'short_name': 'VIANO R',
#    'gender': 'Male',
#    'birth_date': '2002-08-16',
#    'birth_place': 'LA CROIX DES MISSIONS',
#    'birth_country': 'Haiti',
#    'country': 'Haiti',
#    'country_code': 'HAI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': "L'ARGENTIERE-LA-BESSEE",
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1034018-richardson-viano.htm'},
#   {'name': 'VIDOVIC Matej',
#    'short_name': 'VIDOVIC M',
#    'gender': 'Male',
#    'birth_date': '1993-04-14',
#    'birth_place': 'ZAGREB',
#    'birth_country': 'Croatia',
#    'country': 'Croatia',
#    'country_code': 'CRO',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ZAGREB',
#    'residence_country': 'Croatia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035955-matej-vidovic.htm'},
#   {'name': 'VINATZER Alex',
#    'short_name': 'VINATZER A',
#    'gender': 'Male',
#    'birth_date': '1999-09-22',
#    'birth_place': 'BOLZANO',
#    'birth_country': 'Italy',
#    'country': 'Italy',
#    'country_code': 'ITA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SELVA DI VAL GARDENA',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1015106-alex-vinatzer.htm'},
#   {'name': 'VLHOVA Petra',
#    'short_name': 'VLHOVA P',
#    'gender': 'Female',
#    'birth_date': '1995-06-13',
#    'birth_place': 'LIPTOVSKY MIKULAS',
#    'birth_country': 'Slovakia',
#    'country': 'Slovakia',
#    'country_code': 'SVK',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LIPTOVSKY MIKULAS',
#    'residence_country': 'Slovakia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1054100-petra-vlhova.htm'},
#   {'name': 'von APPEN Henrik',
#    'short_name': 'von APPEN H',
#    'gender': 'Male',
#    'birth_date': '1994-12-15',
#    'birth_place': 'SANTIAGO',
#    'birth_country': 'Chile',
#    'country': 'Chile',
#    'country_code': 'CHI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SANTIAGO',
#    'residence_country': 'Chile',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035539-henrik-von-appen.htm'},
#   {'name': 'VUJICIC Jelena',
#    'short_name': 'VUJICIC J',
#    'gender': 'Female',
#    'birth_date': '2001-01-24',
#    'birth_place': 'PLJEVLJA',
#    'birth_country': 'Montenegro',
#    'country': 'Montenegro',
#    'country_code': 'MNE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ZABLJAK',
#    'residence_country': 'Montenegro',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1045526-jelena-vujicic.htm'},
#   {'name': 'VUKADINOVA Eva',
#    'short_name': 'VUKADINOVA E',
#    'gender': 'Female',
#    'birth_date': '2001-03-23',
#    'birth_place': 'SOFIA',
#    'birth_country': 'Bulgaria',
#    'country': 'Bulgaria',
#    'country_code': 'BUL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SOFIA',
#    'residence_country': 'Bulgaria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1016424-eva-vukadinova.htm'},
#   {'name': 'VUKICEVIC Marko',
#    'short_name': 'VUKICEVIC M',
#    'gender': 'Male',
#    'birth_date': '1992-10-27',
#    'birth_place': 'LJUBLJANA',
#    'birth_country': 'Slovenia',
#    'country': 'Serbia',
#    'country_code': 'SRB',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'LJUBLJANA',
#    'residence_country': 'Slovenia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1034932-marko-vukicevic.htm'},
#   {'name': 'WEBB Jeffrey',
#    'short_name': 'WEBB J',
#    'gender': 'Male',
#    'birth_date': '1998-10-27',
#    'birth_place': 'KUALA LUMPUR',
#    'birth_country': 'Malaysia',
#    'country': 'Malaysia',
#    'country_code': 'MAS',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'CHELAN, WA',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1054215-jeffrey-webb.htm'},
#   {'name': 'WEIDLE Kira',
#    'short_name': 'WEIDLE K',
#    'gender': 'Female',
#    'birth_date': '1996-02-24',
#    'birth_place': 'STUTTGART',
#    'birth_country': 'Germany',
#    'country': 'Germany',
#    'country_code': 'GER',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'STARNBERG',
#    'residence_country': 'Germany',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1012722-kira-weidle.htm'},
#   {'name': 'WILES Jacqueline',
#    'short_name': 'WILES J',
#    'gender': 'Female',
#    'birth_date': '1992-07-13',
#    'birth_place': 'PORTLAND, OR',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'PORTLAND, OR',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041219-jacqueline-wiles.htm'},
#   {'name': 'WILKINSON Alix',
#    'short_name': 'WILKINSON A',
#    'gender': 'Female',
#    'birth_date': '2000-08-02',
#    'birth_place': 'MAMMOTH LAKES, CA',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SANTA CRUZ, CA',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041195-alix-wilkinson.htm'},
#   {'name': 'WINDINGSTAD Rasmus',
#    'short_name': 'WINDINGSTAD R',
#    'gender': 'Male',
#    'birth_date': '1993-10-31',
#    'country': 'Norway',
#    'country_code': 'NOR',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ASKER',
#    'residence_country': 'Norway',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1031309-rasmus-windingstad.htm'},
#   {'name': 'WINTERS Luke',
#    'short_name': 'WINTERS L',
#    'gender': 'Male',
#    'birth_date': '1997-04-02',
#    'birth_place': 'GRESHAM, OR',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'GRESHAM, OR',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041226-luke-winters.htm'},
#   {'name': 'WORLEY Tessa',
#    'short_name': 'WORLEY T',
#    'gender': 'Female',
#    'birth_date': '1989-10-04',
#    'birth_place': 'ANNEMASSE',
#    'birth_country': 'France',
#    'country': 'France',
#    'country_code': 'FRA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ALBERTVILLE',
#    'residence_country': 'France',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035780-tessa-worley.htm'},
#   {'name': 'WRIGHT Isabella',
#    'short_name': 'WRIGHT I',
#    'gender': 'Female',
#    'birth_date': '1997-02-10',
#    'birth_place': 'AMERICAN FORK, UT',
#    'birth_country': 'United States of America',
#    'country': 'United States of America',
#    'country_code': 'USA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'PARK CITY, UT',
#    'residence_country': 'United States of America',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1041213-isabella-wright.htm'},
#   {'name': 'XHEPA Denni',
#    'short_name': 'XHEPA D',
#    'gender': 'Male',
#    'birth_date': '2003-05-06',
#    'country': 'Albania',
#    'country_code': 'ALB',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SESTRIERE',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1052881-denni-xhepa.htm'},
#   {'name': 'XU Mingfu',
#    'short_name': 'XU M',
#    'gender': 'Male',
#    'birth_date': '1997-07-17',
#    'birth_place': 'JILIN',
#    'birth_country': "People's Republic of China",
#    'country': "People's Republic of China",
#    'country_code': 'CHN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'JILIN',
#    'residence_country': "People's Republic of China",
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1058048-mingfu-xu.htm'},
#   {'name': 'YULE Daniel',
#    'short_name': 'YULE D',
#    'gender': 'Male',
#    'birth_date': '1993-02-18',
#    'birth_place': 'MARTIGNY',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'MARTIGNY',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1049927-daniel-yule.htm'},
#   {'name': 'YUNG Hau Tsuen Adrian',
#    'short_name': 'YUNG HTA',
#    'gender': 'Male',
#    'birth_date': '2004-08-26',
#    'birth_place': 'HONG KONG',
#    'birth_country': 'Hong Kong, China',
#    'country': 'Hong Kong, China',
#    'country_code': 'HKG',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1055916-hau-tsuen-adrian-yung.htm'},
#   {'name': 'ZABYSTRAN Jan',
#    'short_name': 'ZABYSTRAN J',
#    'gender': 'Male',
#    'birth_date': '1998-01-26',
#    'birth_place': 'KADAN',
#    'birth_country': 'Czech Republic',
#    'country': 'Czech Republic',
#    'country_code': 'CZE',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'CHOMUTOV',
#    'residence_country': 'Czech Republic',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1013900-jan-zabystran.htm'},
#   {'name': 'ZAMPA Adam',
#    'short_name': 'ZAMPA A',
#    'gender': 'Male',
#    'birth_date': '1990-09-13',
#    'birth_place': 'KEZMAROK',
#    'birth_country': 'Czech Republic',
#    'country': 'Slovakia',
#    'country_code': 'SVK',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'VYSOKE TATRY',
#    'residence_country': 'Slovakia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1053028-adam-zampa.htm'},
#   {'name': 'ZAMPA Andreas',
#    'short_name': 'ZAMPA A',
#    'gender': 'Male',
#    'birth_date': '1993-08-13',
#    'birth_place': 'KEZMAROK',
#    'birth_country': 'Slovakia',
#    'country': 'Slovakia',
#    'country_code': 'SVK',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'VYSOKE TATRY',
#    'residence_country': 'Slovakia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1053024-andreas-zampa.htm'},
#   {'name': 'ZANON Nicola',
#    'short_name': 'ZANON N',
#    'gender': 'Male',
#    'birth_date': '1996-12-14',
#    'birth_place': 'CLES',
#    'birth_country': 'Italy',
#    'country': 'Thailand',
#    'country_code': 'THA',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ST. BERNARDO',
#    'residence_country': 'Italy',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1053897-nicola-zanon.htm'},
#   {'name': 'ZENHAEUSERN Ramon',
#    'short_name': 'ZENHAEUSERN R',
#    'gender': 'Male',
#    'birth_date': '1992-05-04',
#    'birth_place': 'BUERCHEN',
#    'birth_country': 'Switzerland',
#    'country': 'Switzerland',
#    'country_code': 'SUI',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'VISP',
#    'residence_country': 'Switzerland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1049930-ramon-zenhaeusern.htm'},
#   {'name': 'ZHANG Yangming',
#    'short_name': 'ZHANG Y',
#    'gender': 'Male',
#    'birth_date': '1994-08-31',
#    'birth_place': 'TONGHUA, JILIN',
#    'birth_country': "People's Republic of China",
#    'country': "People's Republic of China",
#    'country_code': 'CHN',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'JILIN',
#    'residence_country': "People's Republic of China",
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1058047-yangming-zhang.htm'},
#   {'name': 'ZIEBA Hanna',
#    'short_name': 'ZIEBA H',
#    'gender': 'Female',
#    'birth_date': '2005-03-30',
#    'country': 'Poland',
#    'country_code': 'POL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'DZIANISZ',
#    'residence_country': 'Poland',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1032074-hanna-zieba.htm'},
#   {'name': 'ZLATKOV Kamen',
#    'short_name': 'ZLATKOV K',
#    'gender': 'Male',
#    'birth_date': '1997-08-09',
#    'birth_place': 'SOFIA',
#    'birth_country': 'Bulgaria',
#    'country': 'Bulgaria',
#    'country_code': 'BUL',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'SOFIA',
#    'residence_country': 'Bulgaria',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1016407-kamen-zlatkov.htm'},
#   {'name': 'ZUBCIC Filip',
#    'short_name': 'ZUBCIC F',
#    'gender': 'Male',
#    'birth_date': '1993-01-27',
#    'birth_place': 'ZAGREB',
#    'birth_country': 'Croatia',
#    'country': 'Croatia',
#    'country_code': 'CRO',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'ZAGREB',
#    'residence_country': 'Croatia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1035953-filip-zubcic.htm'},
#   {'name': 'ZVEJNIEKS Miks',
#    'short_name': 'ZVEJNIEKS M',
#    'gender': 'Male',
#    'birth_date': '1995-03-08',
#    'birth_place': 'RIGA',
#    'birth_country': 'Latvia',
#    'country': 'Latvia',
#    'country_code': 'LAT',
#    'discipline': 'Alpine Skiing',
#    'discipline_code': 'ALP',
#    'residence_place': 'RIGA',
#    'residence_country': 'Latvia',
#    'url': '../../../en/results/alpine-skiing/athlete-profile-n1038240-miks-zvejnieks.htm'}]}

# %% [markdown]
# <h2>Medals</h2>

# %% [markdown]
# Utilizzando i dataser <code>medals</code> e <code>medals_total</code>, si vuole creare una collezione di documenti in cui ogni documento contiene dati relativi ad un paese partecipante e alle relative medaglie vinte.

# %%
medals.head()
# Out:
#   medal_type  medal_code             medal_date athlete_short_name  \
# 0       Gold           1  2022-02-05 00:00:00.0          ECKHOFF T
# 1       Gold           1  2022-02-05 00:00:00.0      ROEISELAND MO
# 2       Gold           1  2022-02-05 00:00:00.0              BOE T
# 3       Gold           1  2022-02-05 00:00:00.0             BOE JT
# 4     Silver           2  2022-02-05 00:00:00.0  CHEVALIER-BOUCHET
#
#               athlete_name athlete_sex  \
# 0            ECKHOFF Tiril           X
# 1   ROEISELAND Marte Olsbu           X
# 2               BOE Tarjei           X
# 3    BOE Johannes Thingnes           X
# 4  CHEVALIER-BOUCHET Anais           X
#
#                                         athlete_link                    event  \
# 0  ../../../en/results/biathlon/athlete-profile-n...  Mixed Relay 4x6km (W+M)
# 1  ../../../en/results/biathlon/athlete-profile-n...  Mixed Relay 4x6km (W+M)
# 2  ../../../en/results/biathlon/athlete-profile-n...  Mixed Relay 4x6km (W+M)
# 3  ../../../en/results/biathlon/athlete-profile-n...  Mixed Relay 4x6km (W+M)
# 4  ../../../en/results/biathlon/athlete-profile-n...  Mixed Relay 4x6km (W+M)
#
#   country country_code discipline discipline_code
# 0  Norway          NOR   Biathlon             BTH
# 1  Norway          NOR   Biathlon             BTH
# 2  Norway          NOR   Biathlon             BTH
# 3  Norway          NOR   Biathlon             BTH
# 4  France          FRA   Biathlon             BTH

# %%
medals_total.head()
# Out:
#    Order                   Country  Gold  Silver  Bronze  Total  \
# 0      1                    Norway     9       5       7     21
# 1      2                   Germany     8       5       1     14
# 2      3  United States of America     6       5       1     12
# 3      4               Netherlands     6       4       2     12
# 4      5                    Sweden     5       3       3     11
#
#    Order by Total Country Code
# 0               1          NOR
# 1               3          GER
# 2               6          USA
# 3               6          NED
# 4               8          SWE

# %% [markdown]
# Per ogni riga di <code>medals_totals</code> (che è relativa a un determinato paese), si crea un documento che ha come campi le colonne di <code>medals</code> più un campo per ogni tipo di medaglia che conterra un array di oggetti per ogni medaglia di quel tipo vinta dal paese.

# %%
json_medals_total = {}
list_json_medals_total = []

for row in range(medals_total.shape[0]):
    for col in range(medals_total.shape[1]):
        json_medals_total[medals_total.columns[col]] = medals_total.iloc[row,col]

    medals_country = medals.loc[medals['country_code'] == medals_total['Country Code'][row]]  

    list_gold_medals = []
    list_silver_medals = []
    list_bronze_medals = []

    json_medal = {}

    for medal in range(medals_country.shape[0]):
        for col in range(medals_country.shape[1]):
            data = medals_country.iloc[medal,col]
            if isinstance(data, (np.int_, np.intc, np.intp, np.int8,
                            np.int16, np.int32, np.int64, np.uint8,
                            np.uint16, np.uint32, np.uint64)):
                if np.isnan(data):
                            pass
            elif data != data:
                pass
            else:
                json_medal[medals_country.columns[col]] = data
        if medals_country.iloc[medal,1] == 1:    # oro
            list_gold_medals.append(json_medal)
        elif medals_country.iloc[medal,1] == 2: #argento
            list_silver_medals.append(json_medal)
        else:
            list_bronze_medals.append(json_medal)
        
        json_medal = {}

    if len(list_gold_medals) > 0:
        json_medals_total["gold_medals"] = list_gold_medals
    if len(list_silver_medals) > 0:
        json_medals_total["silver_medals"] = list_silver_medals
    if len(list_bronze_medals) > 0:
        json_medals_total["bronze_medals"] = list_bronze_medals

    list_json_medals_total.append(json_medals_total)
    json_medals_total = {}

jsonfile = open("medals.json","w")
for data in list_json_medals_total:
    jsonfile.write(json.dumps(data, indent=3, cls=NumpyEncoder))
jsonfile.close()

# %% [markdown]
# <h2>Events</h2>

# %%
events.head()
# Out:
#                                             location  \
# 0      Yanqing National Alpine Skiing Centre - Speed
# 1      Yanqing National Alpine Skiing Centre - Speed
# 2  Yanqing National Alpine Skiing Centre - Technical
# 3      Yanqing National Alpine Skiing Centre - Speed
# 4  Yanqing National Alpine Skiing Centre - Technical
#
#                    event_stage event_status                       time  \
# 0  Men's Downhill 1st Training     Finished  2022-02-03T11:00:00+08:00
# 1  Men's Downhill 2nd Training     Finished  2022-02-04T12:00:00+08:00
# 2   Women's Giant Slalom Run 1     Finished  2022-02-07T09:30:00+08:00
# 3               Men's Downhill     Finished  2022-02-07T12:00:00+08:00
# 4   Women's Giant Slalom Run 2     Finished  2022-02-07T14:45:00+08:00
#
#                                            event_url discipline_code  \
# 0  ../../../en/results/alpine-skiing/results-men-...             ALP
# 1  ../../../en/results/alpine-skiing/results-men-...             ALP
# 2  ../../../en/results/alpine-skiing/results-wome...             ALP
# 3  ../../../en/results/alpine-skiing/results-men-...             ALP
# 4  ../../../en/results/alpine-skiing/results-wome...             ALP
#
#       discipline
# 0  Alpine Skiing
# 1  Alpine Skiing
# 2  Alpine Skiing
# 3  Alpine Skiing
# 4  Alpine Skiing

# %% [markdown]
# Nel dataset ci sono righe con campi Nan:

# %%
events.columns[events.isna().any()].tolist()
# Out:
# ['event_status', 'time']

# %%
events.loc[events["event_status"].isna()]
# Out:
#                                               location  \
# 15       Yanqing National Alpine Skiing Centre - Speed
# 16       Yanqing National Alpine Skiing Centre - Speed
# 17   Yanqing National Alpine Skiing Centre - Technical
# 18       Yanqing National Alpine Skiing Centre - Speed
# 19   Yanqing National Alpine Skiing Centre - Technical
# ..                                                 ...
# 607                        National Speed Skating Oval
# 608                        National Speed Skating Oval
# 609                        National Speed Skating Oval
# 610                        National Speed Skating Oval
# 611                        National Speed Skating Oval
#
#                                        event_stage event_status  \
# 15                   Women's Downhill 3rd Training          NaN
# 16                                Women's Downhill          NaN
# 17                              Men's Slalom Run 1          NaN
# 18   Women's Alpine Combined Downhill 1st Training          NaN
# 19                              Men's Slalom Run 2          NaN
# ..                                             ...          ...
# 607                                    Men's 1000m          NaN
# 608                    Men's Mass Start Semifinals          NaN
# 609                  Women's Mass Start Semifinals          NaN
# 610                         Men's Mass Start Final          NaN
# 611                       Women's Mass Start Final          NaN
#
#                           time  \
# 15   2022-02-14T13:00:00+08:00
# 16   2022-02-15T11:00:00+08:00
# 17   2022-02-16T10:15:00+08:00
# 18   2022-02-16T10:30:00+08:00
# 19   2022-02-16T13:45:00+08:00
# ..                         ...
# 607  2022-02-18T16:30:00+08:00
# 608  2022-02-19T15:00:00+08:00
# 609  2022-02-19T15:45:00+08:00
# 610  2022-02-19T16:30:00+08:00
# 611  2022-02-19T17:00:00+08:00
#
#                                              event_url discipline_code  \
# 15   ../../../en/results/alpine-skiing/results-wome...             ALP
# 16   ../../../en/results/alpine-skiing/results-wome...             ALP
# 17   ../../../en/results/alpine-skiing/results-men-...             ALP
# 18   ../../../en/results/alpine-skiing/results-wome...             ALP
# 19   ../../../en/results/alpine-skiing/results-men-...             ALP
# ..                                                 ...             ...
# 607  ../../../en/results/speed-skating/results-men-...             SSK
# 608  ../../../en/results/speed-skating/results-men-...             SSK
# 609  ../../../en/results/speed-skating/results-wome...             SSK
# 610  ../../../en/results/speed-skating/results-men-...             SSK
# 611  ../../../en/results/speed-skating/results-wome...             SSK
#
#         discipline
# 15   Alpine Skiing
# 16   Alpine Skiing
# 17   Alpine Skiing
# 18   Alpine Skiing
# 19   Alpine Skiing
# ..             ...
# 607  Speed Skating
# 608  Speed Skating
# 609  Speed Skating
# 610  Speed Skating
# 611  Speed Skating
#
# [203 rows x 7 columns]

# %% [markdown]
# Queste corrispondono ad eventi non ancora disputati.

# %%
json_events = {}
list_json_events = []

for row in range(events.shape[0]):
    for col in range(events.shape[1]):
        data = events.iloc[row,col]
        if isinstance(data, (np.int_, np.intc, np.intp, np.int8,
                            np.int16, np.int32, np.int64, np.uint8,
                            np.uint16, np.uint32, np.uint64)):
                if np.isnan(data):
                            pass
        elif data != data:
            pass
        else:
           json_events[events.columns[col]] = data
    
    list_json_events.append(json_events)
    json_events = {}

jsonfile = open("events.json","w")
for data in list_json_events:
    jsonfile.write(json.dumps(data, indent=3, cls=NumpyEncoder))
jsonfile.close()
